# %% [markdown]
# # PostgresChatMessageHistory

# %%
from uitls import generate_user_id

user_id = generate_user_id()
user_id
# Out:
# 'd0117d2c-6b29-4d66-b1b9-b25ca4827696'

# %%
from chat import chat_system


response = chat_system("ما هو الذكاء الاصطناعي؟", user_id)
print(response)
# Out:
# content='الذكاء الاصطناعي (Artificial Intelligence - AI) هو فرع من علوم الحاسوب يهدف إلى إنشاء أنظمة أو برامج قادرة على محاكاة الذكاء البشري أو تجاوزه في أداء مهام معينة. يشمل ذلك القدرة على:\n\n- **التعلم** (مثل التعلّم من البيانات والخبرات — ويدعى ذلك التعلّم الآلي أو Machine Learning)،  \n- **الاستدلال** (اتخاذ قرارات أو استنتاجات بناءً على معلومات متوفرة)،  \n- **الفهم اللغوي** (مثل فهم اللغة الطبيعية والرد عليها — كما في مساعدات الصوت أو الترجمة)،  \n- **الإدراك الحسي** (مثل التعرف على الصور أو الأصوات)،  \n- **التفكير المنطقي والحلّ المبتكر للمشكلات**.\n\nأمثلة على تطبيقات الذكاء الاصطناعي تشمل:  \n- المساعدات الذكية (مثل Siri وGoogle Assistant)،  \n- السيارات ذاتية القيادة،  \n- أنظمة التوصية (مثل التي تُستخدم في نتفليكس أو أمازون)،  \n- الترجمة الآلية (مثل Google Translate)،  \n- الروبوتات الصناعية،  \n- أدوات توليد النصوص والصور (مثل ChatGPT أو Midjourney).\n\nببساطة: الذكاء الاصطناعي هو جعل الآلات "تتصرّف" بذكاء — أي بقدرة على التكيّف، والتعلّم، واتخاذ قرارات مستقلة نسبيًا.
# ...

# %%
response = chat_system("شو اخر سؤال سألتك اياه؟", user_id)
print(response)
# Out:
# content='السؤال السابق الذي سألته كان:  \n**"ما هو الذكاء الاصطناعي؟"**\n\nوقد أجبتُ به تفصيلٍ شامٍّ عن مفهوم الذكاء الاصطناعي، وأمثلة على تطبيقاته، وخصائصه الأساسية. 😊\n\nهل هناك شيء معيّن ترغب في تعميقه أو معرفته عن الذكاء الاصطناعي؟' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 803, 'total_tokens': 908, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen/qwen3-coder-next', 'system_fingerprint': '', 'id': '732d83905f9f2b908b17c902bac839a9', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ddf69-a38b-76e1-8d96-8235d97e65a8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 803, 'output_tokens': 105, 'total_tokens': 908, 'input_token_details': {}, 'output_token_details': {}}

# %% [markdown]
# ## 1: split ipynb to pythons files
# ## 2: create api system on these files
# ## 3: Tasks
