# %%
class Car:
    wheels=4                 # class atribute
    speed_limt=120
    def __init__(self, color, model, brand):  # object attributes
        self.color=color
        self.model=model
        self.brand=brand

    def drive(self):            # object methods
        print(f' the color is {self.color} and the model is {self.model} and the brand= {self.brand}')

    @classmethod                # class method
    def change_speed(cls, new_speed):
        cls.speed_limt=new_speed
        print(f'speed limt changed to {cls.speed_limt}')

# %%
class Big_car(Car):

# %%
car1=Car('red', 2022, 'BMW')  # create objects
car2=Car('black', 2023, 'BMW')
car3=Car('orange', 2025,'ffdgshj')

car3.drive()
# Out:
#  the color is orange and the model is 2025 and the brand= ffdgshj

# %%
Car.speed_limt=300

# %%
Car.speed_limt
# Out:
# 300

# %%
car3.drive()
# Out:
#  the color is orange and the model is 2025 and the brand= ffdgshj

# %%
Car.drive(car3)
# Out:
#  the color is orange and the model is 2025 and the brand= ffdgshj

# %%
car1.color
# Out:
# 'red'

# %%
Car.speed_limt
# Out:
# 300

# %%
Car.change_speed(200)
# Out:
# speed limt changed to 200

# %%
Car.speed_limt
# Out:
# 200

# %%
def drive(self):

# %%
class Animal:
    def speak(self):
        return "Sound"

class Dog(Animal):
    def speak(self):
        return "Woof"

class Cat(Animal):
    def speak(self):
        return "Meow"

# %%
class Father:
    def __init__(self, name):
        self.name=name

    def sleep(self):
        return ('seelp on right')
    
class Mother:
    def __init__(self,name):
        self.name=name

    def sleep(self):
        return ('sleep on left')
    
class Boy(Father, Mother):
    def __init__(self, name):
        self.name=name

    def sleep(self, hours):
        return (f'sleep on middle and for {hours}')
    
    def sleep_(self):
        return ('sleep on left')

# %%
boy1=Boy('Ahmed')
boy1.sleep(4)
# Out:
# 'sleep on middle and for 4'

# %%
class Father:
    def __init__(self, name):
        self.name=name

    def sleep(self):
        return ('seelp on right')
    
class Mother:
    def __init__(self,name):
        self.name=name

    def sleep(self):
        return ('sleep on left')
    
class Boy(Father, Mother):
    def __init__(self, name):
        self.name=name

# %%
boy1=Boy('Ahmed')
boy1.sleep()
# Out:
# 'seelp on right'

# %%
class A:
    def hi(self):
        print("A")

class B(A):
    def hi(self):
        print("B")

class C(A):
    def hi(self):
        print("C")

class D(B, C):
    pass

d = D()
d.hi()
# Out:
# B

# %%
class A:
    def hi(self):
        print("A")

class B(A):
    def hi(self):
        print("B")

class C(A):
    def hi(self):
        print("C")

class D(B, C):
    pass

d = D()
d.hi()
# Out:
# B

# %%
class Dog:
    def speak(self):
        return "Woof!"

class Cat:
    def speak__(self):
        return "Meow!"

class Duck:
    def speak(self):
        return "Quack!"

# %%
object_d=Dog()
object_cat=Cat()

# %%
def vbcndxmgdh(a):
    print(a.speak())

# %%
vbcndxmgdh(object_d)
# Out:
# Woof!

# %%
vbcndxmgdh(object_cat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 vbcndxmgdh(object_cat)
#
# Cell In[11], line 2, in vbcndxmgdh(a)
#       1 def vbcndxmgdh(a):
# ----> 2     print(a.speak())
#
# AttributeError: 'Cat' object has no attribute 'speak'

# %%
class Bankaccount:
    def __init__(self,name, balance ):
        self.name=name
        self.balance=balance
        self.account_number= Bankaccount.generate_account_number()

    
    def depsite(self,amount):
        self.balance +=amount
        print(f'the Deposite is Done and your balance = {self.balance}')


    def withdrow(self, amount):
        if amount > self.balance:
            print('your balance is not enough ')
        else:
            self.balance -=amount
            print(f'the withdrow is Done and your balance = {self.balance}')


    @staticmethod
    def generate_account_number():
        from random import randint
        return randint(100000000000000, 9999999999999999)
    

customer1=Bankaccount('lobna', 2000)
customer1.withdrow(3000)
customer1.generate_account_number()
# Out:
# your balance is not enough
# 2382374599254888

# %%
class Bankaccount:
    def __init__(self,name, balance ):
        self.name=name
        self.balance=balance
        self.account_number= Bankaccount.generate_account_number()

    
    def depsite(self,amount):
        self.balance +=amount
        print(f'the Deposite is Done and your balance = {self.balance}')


    def withdrow(self, amount):
        if amount > self.balance:
            print('your balance is not enough ')
        else:
            self.balance -=amount
            print(f'the withdrow is Done and your balance = {self.balance}')


    @staticmethod
    def generate_account_number():
        from random import randint
        return randint(100000000000000, 9999999999999999)
    

    Acounts=[]
    while True:
        name=input('enter u name / exit')
        balance=float(input('enter you balance'))
        customer=Bankaccount(name,balance )
        Acounts.append(customer)

        print(f'Your account number ={customer.account_number}')

        Action=input('what is Action ( 1.depsite /2.withdrow / 3.exit)')
        if Action=='depsite':
            customer.depsite(float(input(' Enter the Amount')))

        elif Action=='withdrow':
            customer.withdrow(float(input(' Enter the Amount')))

        elif Action =='exit':
            break
# Out:
# Your account number =8335988123811968

# %%
ob.attribute
ob.method()
Bank_Account.method()

# %%
def generate_account_number():
    from random import randint
    return randint(100000000000000, 9999999999999999)

# %%
generate_account_number()
# Out:
# 3619651951256302

# %%
class Bankaccount:
    def __init__(self,name, balance ):
        self.name=name
        self.balance=balance
        self.account_number= Bankaccount.generate_account_number()

    
    def depsite(self,amount):
        self.balance +=amount
        print(f'the Deposite is Done and your balance = {self.balance}')


    def withdrow(self, amount):
        if amount > self.balance:
            print('your balance is not enough ')
        else:
            self.balance -=amount
            print(f'the withdrow is Done and your balance = {self.balance}')


    @staticmethod
    def generate_account_number():
        from random import randint
        return randint(100000000000000, 9999999999999999)
    

    Acounts=[]

    while True:
        name=input('enter u name / exit')

        if name == 'exit':
            print('off')
            for acc in Acounts:
                print(acc.name)
                print(acc.account_number)
            break

        balance=float(input('enter you balance'))
        customer=Bankaccount(name,balance )
        Acounts.append(customer)

        while True:

            print(f'Your account number ={customer.account_number}')

            Action=input('what is Action ( 1.depsite /2.withdrow / 3.exit)')
            if Action=='depsite':
                customer.depsite(float(input(' Enter the Amount')))

            elif Action=='withdrow':
                customer.withdrow(float(input(' Enter the Amount')))

            elif Action =='exit':
                break
            else:
                print('Invalid Action')
# Out:
# Your account number =6576512756307172
# the Deposite is Done and your balance = 3000.0
# Your account number =6576512756307172
# Your account number =3406280905903167
# the withdrow is Done and your balance = 3000.0
# Your account number =3406280905903167
# off
# lobna
# 6576512756307172
# Sara
# 3406280905903167
